# %%
import pandas as pd

# %%
df = pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-01.parquet')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 df = pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-01.parquet')
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/io/parquet.py:491, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, **kwargs)
#     437 @doc(storage_options=_shared_docs["storage_options"])
#     438 def read_parquet(
#     439     path,
#    (...)
#     444     **kwargs,
#     445 ) -> DataFrame:
#     446     """
#     447     Load a parquet object from the file path, returning a DataFrame.
#     448
#    (...)
#     489     DataFrame
#     490     """
# --> 491     impl = get_engine(engine)
#     493     return impl.read(
#     494         path,
#     495         columns=columns,
#    (...)
#     498         **kwargs,
#     499     )
#
# ...

# %%
pip install pyarrow
# Out:
# ...
#      |████████████████████████████████| 42.7 MB 75.7 MB/s eta 0:00:01   |█████▉                          | 7.8 MB 1.2 MB/s eta 0:00:29     |███████████████████▍            | 25.9 MB 1.2 MB/s eta 0:00:14��█████████████       | 33.3 MB 1.2 MB/s eta 0:00:08
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df = pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-01.parquet')

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2025-01-01 00:18:38   2025-01-01 00:26:59              1.0
# 1         1  2025-01-01 00:32:40   2025-01-01 00:35:13              1.0
# 2         1  2025-01-01 00:44:04   2025-01-01 00:46:01              1.0
# 3         2  2025-01-01 00:14:27   2025-01-01 00:20:01              3.0
# 4         2  2025-01-01 00:21:34   2025-01-01 00:25:06              3.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.60         1.0                  N           229           237
# 1           0.50         1.0                  N           236           237
# 2           0.60         1.0                  N           141           141
# 3           0.52         1.0                  N           244           244
# 4           0.66         1.0                  N           244           116
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
import sklearn

# %%
sklearn.__version__
# Out:
# '1.0.2'

# %%
df = pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-01.parquet')

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
# 1         2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2         2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3         1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4         2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.97         1.0                  N           161           141
# 1           1.10         1.0                  N            43           237
# 2           2.51         1.0                  N            48           238
# 3           1.90         1.0                  N           138             7
# 4           1.43         1.0                  N           107            79
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
import pandas as pd

# %%
19
# Out:
# 19

# %%
Q3- 98, Q4 - 515, Q5- 7.64, Q6- 7.81
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 Q3- 98, Q4 - 515, Q5- 7.64, Q6- 7.81
#
# NameError: name 'Q3' is not defined

# %%
import pandas as pd
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df_train = pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-01.parquet')
df_val = pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-02.parquet')

# %%
df_train['duration'] = (df_train.dropOff_datetime - df_train.pickup_datetime).dt.total_seconds() / 60
df_val['duration'] = (df_val.dropOff_datetime - df_val.pickup_datetime).dt.total_seconds() / 60
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 df_train['duration'] = (df_train.dropOff_datetime - df_train.pickup_datetime).dt.total_seconds() / 60
#       2 df_val['duration'] = (df_val.dropOff_datetime - df_val.pickup_datetime).dt.total_seconds() / 60
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dropOff_datetime'

# %%
df_train['tpep_pickup_datetime'] = pd.to_datetime(df_train['tpep_pickup_datetime'])
df_train['tpep_dropoff_datetime'] = pd.to_datetime(df_train['tpep_dropoff_datetime'])

df_val['tpep_pickup_datetime'] = pd.to_datetime(df_val['tpep_pickup_datetime'])
df_val['tpep_dropoff_datetime'] = pd.to_datetime(df_val['tpep_dropoff_datetime'])

# %%
df_train['duration'] = (df_train.dropOff_datetime - df_train.pickup_datetime).dt.total_seconds() / 60
df_val['duration'] = (df_val.dropOff_datetime - df_val.pickup_datetime).dt.total_seconds() / 60
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 df_train['duration'] = (df_train.dropOff_datetime - df_train.pickup_datetime).dt.total_seconds() / 60
#       2 df_val['duration'] = (df_val.dropOff_datetime - df_val.pickup_datetime).dt.total_seconds() / 60
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dropOff_datetime'

# %%
df_train['duration'] = (
    df_train['tpep_dropoff_datetime'] - df_train['tpep_pickup_datetime']
).dt.total_seconds() / 60

df_val['duration'] = (
    df_val['tpep_dropoff_datetime'] - df_val['tpep_pickup_datetime']
).dt.total_seconds() / 60
